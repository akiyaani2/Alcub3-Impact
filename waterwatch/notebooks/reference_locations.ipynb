# %% [markdown]
# # BasinKit Reference Locations
#
# Load the curated benchmark pack and run a small live benchmark sample.

# %%
from waterwatch.benchmarks import load_reference_locations, run_reference_benchmarks

locations = load_reference_locations()
locations[:2]

# %%
results = run_reference_benchmarks(limit=2, timeout=15.0)
results
