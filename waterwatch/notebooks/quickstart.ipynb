# %% [markdown]
# # BasinKit Quickstart
#
# Minimal notebook for trying the public water-intelligence toolkit.

# %%
from waterwatch import WaterIntel

intel = WaterIntel(timeout=15.0)
pulse = intel.pulse(lat=33.4484, lon=-112.0740)
pulse["score"], pulse["quality"]["quality_grade"], pulse["drought"]["drought_level"]

# %%
intel.close()
